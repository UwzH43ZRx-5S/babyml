# %%
import numpy as np
import pandas as pd

# %%
test = pd.read_csv('https://raw.githubusercontent.com/UwzH43ZRx-5S/kaggledata/main/TitanicData/test.csv?token=GHSAT0AAAAAACBHJYGGSZ3YZFEB2Y37RHUCZBUQY5Q')
train = pd.read_csv('https://raw.githubusercontent.com/UwzH43ZRx-5S/kaggledata/main/TitanicData/train.csv?token=GHSAT0AAAAAACBHJYGHV4HL6ZPDQZUOUNHQZBUQ3YQ')
gender_submission = pd.read_csv('https://raw.githubusercontent.com/UwzH43ZRx-5S/kaggledata/main/TitanicData/train.csv?token=GHSAT0AAAAAACBHJYGHKG46V5GRKCJSO7PGZBUQZQQ')
#Predicts that all females survived, all males died

train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
women = train.loc[train.Sex == 'female']["Survived"]
rate_women = (round(sum(women)/len(women),2))

print("% of women who survived:", rate_women)

men = train.loc[train.Sex == 'male']["Survived"]
rate_men = (round(sum(men)/len(men),2))

print("% of men who survived:", rate_men)
# Out:
# % of women who survived: 0.74
# % of men who survived: 0.19

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
y = train["Survived"]

features = ["Pclass", "Sex", "SibSp", "Parch"]
X = pd.get_dummies(train[features])
X_test = pd.get_dummies(test[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test.PassengerId, 'Survived': predictions})
output
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
